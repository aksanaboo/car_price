# %% [markdown]
# <a href="https://colab.research.google.com/github/aksanaboo/car_price/blob/main/legoEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lego = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/lego_sets_and_themes.csv')

# %%
lego.head()
# Out:
#   set_number                        set_name  year_released  number_of_parts  \
# 0      001-1                           Gears         1965.0             43.0
# 1      002-1  4.5V Samsonite Gears Motor Set         1965.0              3.0
# 2     1030-1  TECHNIC I: Simple Machines Set         1985.0            210.0
# 3     1038-1              ERBIE the Robo-Car         1985.0            120.0
# 4     1039-1            Manual Control Set 1         1986.0             39.0
#
#                                            image_url theme_name
# 0   https://cdn.rebrickable.com/media/sets/001-1.jpg    Technic
# 1   https://cdn.rebrickable.com/media/sets/002-1.jpg    Technic
# 2  https://cdn.rebrickable.com/media/sets/1030-1.jpg    Technic
# 3  https://cdn.rebrickable.com/media/sets/1038-1.jpg    Technic
# 4  https://cdn.rebrickable.com/media/sets/1039-1.jpg    Technic

# %%
lego.columns
# Out:
# Index(['set_number', 'set_name', 'year_released', 'number_of_parts',
#        'image_url', 'theme_name'],
#       dtype='object')

# %%
lego.shape
# Out:
# (21503, 6)

# %%
lego.isnull().sum()
# Out:
# set_number         7
# set_name           7
# year_released      7
# number_of_parts    7
# image_url          7
# theme_name         0
# dtype: int64

# %%
#no duplicates present
lego.duplicated().sum()
# Out:
# 0

# %%
null_values = lego.isnull().sum()
null_values
# Out:
# set_number         7
# set_name           7
# year_released      7
# number_of_parts    7
# image_url          7
# theme_name         0
# dtype: int64

# %%
null_val = lego[lego.isnull().any(axis=1)]

# %%
null_val.shape
# Out:
# (7, 6)

# %%
null_val
# Out:
#       set_number set_name  year_released  number_of_parts image_url  \
# 702          NaN      NaN            NaN              NaN       NaN
# 2571         NaN      NaN            NaN              NaN       NaN
# 2917         NaN      NaN            NaN              NaN       NaN
# 4935         NaN      NaN            NaN              NaN       NaN
# 5616         NaN      NaN            NaN              NaN       NaN
# 9165         NaN      NaN            NaN              NaN       NaN
# 14764        NaN      NaN            NaN              NaN       NaN
#
#                              theme_name
# 702                         Basic Model
# 2571                        Speed Racer
# 2917                            Pirates
# 4935                           RC Train
# 5616                        Adventurers
# 9165                           Fabuland
# 14764  The Hobbit and Lord of the Rings

# %%
lego = lego.dropna()

# %%
lego.theme_name.value_counts()
# Out:
# Star Wars            913
# Technic              857
# Books                699
# Key Chain            693
# Friends              568
#                     ...
# Jurassic Park III      2
# Legoland               1
# Adventurers            1
# Aquazone               1
# Mini                   1
# Name: theme_name, Length: 380, dtype: int64

# %%
lego.year_released.value_counts()
# Out:
# 2021.0    1142
# 2019.0    1023
# 2020.0    1014
# 2022.0    1008
# 2018.0     934
#           ...
# 1950.0       6
# 1949.0       5
# 1953.0       4
# 1959.0       4
# 1960.0       3
# Name: year_released, Length: 73, dtype: int64

# %%
lego.head()
# Out:
#   set_number                        set_name  year_released  number_of_parts  \
# 0      001-1                           Gears         1965.0             43.0
# 1      002-1  4.5V Samsonite Gears Motor Set         1965.0              3.0
# 2     1030-1  TECHNIC I: Simple Machines Set         1985.0            210.0
# 3     1038-1              ERBIE the Robo-Car         1985.0            120.0
# 4     1039-1            Manual Control Set 1         1986.0             39.0
#
#                                            image_url theme_name
# 0   https://cdn.rebrickable.com/media/sets/001-1.jpg    Technic
# 1   https://cdn.rebrickable.com/media/sets/002-1.jpg    Technic
# 2  https://cdn.rebrickable.com/media/sets/1030-1.jpg    Technic
# 3  https://cdn.rebrickable.com/media/sets/1038-1.jpg    Technic
# 4  https://cdn.rebrickable.com/media/sets/1039-1.jpg    Technic

# %%
#Data Visualisation

# %%
num_parts = lego.groupby('year_released')['number_of_parts'].mean()

# %%
num_parts = pd.DataFrame(num_parts)

# %%
num_parts.head()
# Out:
#                number_of_parts
# year_released
# 1949.0               99.600000
# 1950.0                1.000000
# 1953.0               12.500000
# 1954.0                8.357143
# 1955.0               12.205128

# %%
num_parts = num_parts.reset_index()

# %%
num_parts.head()
# Out:
#    year_released  number_of_parts
# 0         1949.0        99.600000
# 1         1950.0         1.000000
# 2         1953.0        12.500000
# 3         1954.0         8.357143
# 4         1955.0        12.205128

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(x=num_parts['year_released'],y=num_parts['number_of_parts'],color='olivedrab')
sns.set_style('darkgrid')

plt.xlabel('Year of Release')
plt.ylabel('Number of Parts')
plt.title('Lego Trend over time',color='darkolivegreen')
plt.show()

# %%
# conclusion = increase in lego parts with time

# %%
theme = lego.groupby('year_released')['theme_name'].count()

# %%
theme = pd.DataFrame(theme)

# %%
theme.head()
# Out:
#                theme_name
# year_released
# 1949.0                  5
# 1950.0                  6
# 1953.0                  4
# 1954.0                 14
# 1955.0                 39

# %%
theme = theme.reset_index()

# %%
theme.head()
# Out:
#    year_released  theme_name
# 0         1949.0           5
# 1         1950.0           6
# 2         1953.0           4
# 3         1954.0          14
# 4         1955.0          39

# %%
theme.rename(columns={'theme_name':'number_of_themes'},inplace=True)

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(x=theme['year_released'],y=theme['number_of_themes'],color='lightcoral')
sns.set_style('darkgrid')

plt.xlabel('Year of Release')
plt.ylabel('Number of themes')
plt.title('Lego Trend over time',color='indianred')
plt.show()

# %%
#conclusion = increase in lego themes with time

# %%
# 380 different themes
lego.theme_name.value_counts()
# Out:
# Star Wars            913
# Technic              857
# Books                699
# Key Chain            693
# Friends              568
#                     ...
# Jurassic Park III      2
# Legoland               1
# Adventurers            1
# Aquazone               1
# Mini                   1
# Name: theme_name, Length: 380, dtype: int64

# %%
# when does each theme released year

# %%
year = lego[['year_released','theme_name']]

# %%
year.head()
# Out:
#    year_released theme_name
# 0         1965.0    Technic
# 1         1965.0    Technic
# 2         1985.0    Technic
# 3         1985.0    Technic
# 4         1986.0    Technic

# %%
first_release_years = year.groupby('theme_name')['year_released'].min()

# %%
first_release_years.reset_index()
# Out:
#           theme_name  year_released
# 0                12V         1969.0
# 1          4 Juniors         2003.0
# 2               4.5V         1966.0
# 3                 9V         1991.0
# 4    Action Wheelers         2000.0
# ..               ...            ...
# 375            X-Pod         2004.0
# 376             Xtra         2018.0
# 377             Znap         1998.0
# 378          Zooters         2001.0
# 379             eLAB         1999.0
#
# [380 rows x 2 columns]

# %%
final_year = year.groupby('theme_name')['year_released'].max()

# %%
final_year.reset_index()
# Out:
#           theme_name  year_released
# 0                12V         1986.0
# 1          4 Juniors         2004.0
# 2               4.5V         1985.0
# 3                 9V         2007.0
# 4    Action Wheelers         2001.0
# ..               ...            ...
# 375            X-Pod         2006.0
# 376             Xtra         2021.0
# 377             Znap         1999.0
# 378          Zooters         2001.0
# 379             eLAB         1999.0
#
# [380 rows x 2 columns]

# %%
first_release_years = pd.DataFrame(first_release_years)
final_year = pd.DataFrame(final_year)

# %%
first_release_years.reset_index(inplace=True)

# %%
final_year.reset_index()
# Out:
#           theme_name  year_released
# 0                12V         1986.0
# 1          4 Juniors         2004.0
# 2               4.5V         1985.0
# 3                 9V         2007.0
# 4    Action Wheelers         2001.0
# ..               ...            ...
# 375            X-Pod         2006.0
# 376             Xtra         2021.0
# 377             Znap         1999.0
# 378          Zooters         2001.0
# 379             eLAB         1999.0
#
# [380 rows x 2 columns]

# %%
final_year.rename(columns={'year_released':'final_year_launched'},inplace=True)

# %%
final_year.head()
# Out:
#                  final_year_launched
# theme_name
# 12V                           1986.0
# 4 Juniors                     2004.0
# 4.5V                          1985.0
# 9V                            2007.0
# Action Wheelers               2001.0

# %%
lego_theme = pd.merge(first_release_years,final_year,on='theme_name', how='inner')

# %%
lego_theme
# Out:
#           theme_name  year_released  final_year_launched
# 0                12V         1969.0               1986.0
# 1          4 Juniors         2003.0               2004.0
# 2               4.5V         1966.0               1985.0
# 3                 9V         1991.0               2007.0
# 4    Action Wheelers         2000.0               2001.0
# ..               ...            ...                  ...
# 375            X-Pod         2004.0               2006.0
# 376             Xtra         2018.0               2021.0
# 377             Znap         1998.0               1999.0
# 378          Zooters         2001.0               2001.0
# 379             eLAB         1999.0               1999.0
#
# [380 rows x 3 columns]

# %%
lego_theme['years_active'] = lego_theme['final_year_launched']-lego_theme['year_released']

# %%
lego_theme.head()
# Out:
#         theme_name  year_released  final_year_launched  years_active
# 0              12V         1969.0               1986.0          17.0
# 1        4 Juniors         2003.0               2004.0           1.0
# 2             4.5V         1966.0               1985.0          19.0
# 3               9V         1991.0               2007.0          16.0
# 4  Action Wheelers         2000.0               2001.0           1.0

# %%
lego_theme = lego_theme.sort_values(by='years_active', ascending=False)

# %%
lego_theme.head()
# Out:
#         theme_name  year_released  final_year_launched  years_active
# 320   Supplemental         1949.0               2023.0          74.0
# 27       Basic Set         1953.0               2023.0          70.0
# 39           Books         1955.0               2023.0          68.0
# 79   Database Sets         1955.0               2023.0          68.0
# 56         Classic         1960.0               2023.0          63.0

# %%
lego_theme.years_active.describe()
# Out:
# count    380.000000
# mean       9.715789
# std       14.698671
# min        0.000000
# 25%        0.000000
# 50%        3.000000
# 75%       13.250000
# max       74.000000
# Name: years_active, dtype: float64

# %%
lego_theme['active'] = lego_theme['final_year_launched'].apply(lambda x: 'active' if x == 2023.0 else 'inactive' )

# %%
lego_theme.head()
# Out:
#         theme_name  year_released  final_year_launched  years_active  active
# 320   Supplemental         1949.0               2023.0          74.0  active
# 27       Basic Set         1953.0               2023.0          70.0  active
# 39           Books         1955.0               2023.0          68.0  active
# 79   Database Sets         1955.0               2023.0          68.0  active
# 56         Classic         1960.0               2023.0          63.0  active

# %%
lego_theme.active.value_counts()
# Out:
# inactive    298
# active       82
# Name: active, dtype: int64

# %%
currently_active = (lego_theme.active == 'active') & (lego_theme.years_active > 0.0)

# %%
lego_theme[currently_active]
# Out:
#           theme_name  year_released  final_year_launched  years_active  active
# 320     Supplemental         1949.0               2023.0          74.0  active
# 27         Basic Set         1953.0               2023.0          70.0  active
# 39             Books         1955.0               2023.0          68.0  active
# 79     Database Sets         1955.0               2023.0          68.0  active
# 56           Classic         1960.0               2023.0          63.0  active
# ..               ...            ...                  ...           ...     ...
# 175         LEGO Art         2020.0               2023.0           3.0  active
# 318      Super Mario         2020.0               2023.0           3.0  active
# 315           Stuntz         2021.0               2023.0           2.0  active
# 196  Marvel Series 1         2021.0               2023.0           2.0  active
# 22            Avatar         2022.0               2023.0           1.0  active
#
# [76 rows x 5 columns]

# %%
# popular themes stay in production for 3 or more years

# %%
popular_theme = (lego_theme.active == 'active') & (lego_theme.years_active > 3.0)

# %%
popular = lego_theme[popular_theme]
popular.head()
# Out:
#         theme_name  year_released  final_year_launched  years_active  active
# 320   Supplemental         1949.0               2023.0          74.0  active
# 27       Basic Set         1953.0               2023.0          70.0  active
# 39           Books         1955.0               2023.0          68.0  active
# 79   Database Sets         1955.0               2023.0          68.0  active
# 56         Classic         1960.0               2023.0          63.0  active

# %%
plt.figure(figsize=(20, 20))
sns.barplot(x='years_active', y='theme_name',data=popular, palette='mako')
plt.xlabel('Number of active years including 2023')
plt.ylabel('Theme name')
plt.title('Popular themes since 1949',color='lightslategrey')
plt.show()

# %%
lego.head()
# Out:
#   set_number                        set_name  year_released  number_of_parts  \
# 0      001-1                           Gears         1965.0             43.0
# 1      002-1  4.5V Samsonite Gears Motor Set         1965.0              3.0
# 2     1030-1  TECHNIC I: Simple Machines Set         1985.0            210.0
# 3     1038-1              ERBIE the Robo-Car         1985.0            120.0
# 4     1039-1            Manual Control Set 1         1986.0             39.0
#
#                                            image_url theme_name
# 0   https://cdn.rebrickable.com/media/sets/001-1.jpg    Technic
# 1   https://cdn.rebrickable.com/media/sets/002-1.jpg    Technic
# 2  https://cdn.rebrickable.com/media/sets/1030-1.jpg    Technic
# 3  https://cdn.rebrickable.com/media/sets/1038-1.jpg    Technic
# 4  https://cdn.rebrickable.com/media/sets/1039-1.jpg    Technic

# %%
lego.isnull().sum()
# Out:
# set_number         0
# set_name           0
# year_released      0
# number_of_parts    0
# image_url          0
# theme_name         0
# dtype: int64

# %%
lego.theme_name.value_counts()
# Out:
# Star Wars            913
# Technic              857
# Books                699
# Key Chain            693
# Friends              568
#                     ...
# Jurassic Park III      2
# Legoland               1
# Adventurers            1
# Aquazone               1
# Mini                   1
# Name: theme_name, Length: 380, dtype: int64

# %%
all_the_rage = pd.DataFrame(lego.theme_name.value_counts())

# %%
all_the_rage.head()
# Out:
#            theme_name
# Star Wars         913
# Technic           857
# Books             699
# Key Chain         693
# Friends           568

# %%
all_the_rage.reset_index(inplace=True)

# %%
all_the_rage
# Out:
#                  index  theme_name
# 0            Star Wars         913
# 1              Technic         857
# 2                Books         699
# 3            Key Chain         693
# 4              Friends         568
# ..                 ...         ...
# 375  Jurassic Park III           2
# 376           Legoland           1
# 377        Adventurers           1
# 378           Aquazone           1
# 379               Mini           1
#
# [380 rows x 2 columns]

# %%
all_the_rage.rename(columns={'index':'theme_name','theme_name':'count'},inplace=True)

# %%
all_the_rage.head()
# Out:
#   theme_name  count
# 0  Star Wars    913
# 1    Technic    857
# 2      Books    699
# 3  Key Chain    693
# 4    Friends    568

# %%
all_the_rage.describe()
# Out:
#             count
# count  380.000000
# mean    56.568421
# std    111.887019
# min      1.000000
# 25%     10.000000
# 50%     19.000000
# 75%     51.000000
# max    913.000000

# %%
#merge popular and all_the_rage
in_demand = pd.merge(popular,all_the_rage,on='theme_name', how='inner')

# %%
in_demand.head()
# Out:
#       theme_name  year_released  final_year_launched  years_active  active  \
# 0   Supplemental         1949.0               2023.0          74.0  active
# 1      Basic Set         1953.0               2023.0          70.0  active
# 2          Books         1955.0               2023.0          68.0  active
# 3  Database Sets         1955.0               2023.0          68.0  active
# 4        Classic         1960.0               2023.0          63.0  active
#
#    count
# 0    437
# 1    478
# 2    699
# 3    100
# 4     70

# %%
active_group = (in_demand['active'] == 'active') & (in_demand['count'] >= 200)

# %%
sought_after = in_demand[active_group]

# %%
sought_after.head()
# Out:
#       theme_name  year_released  final_year_launched  years_active  active  \
# 0   Supplemental         1949.0               2023.0          74.0  active
# 1      Basic Set         1953.0               2023.0          70.0  active
# 2          Books         1955.0               2023.0          68.0  active
# 6        Technic         1965.0               2023.0          58.0  active
# 16          Town         1978.0               2023.0          45.0  active
#
#     count
# 0     437
# 1     478
# 2     699
# 6     857
# 16    418

# %%
sought_after.shape
# Out:
# (17, 6)

# %%
len(sought_after['count'])
# Out:
# 17

# %%
len(sought_after['theme_name'])
# Out:
# 17

# %%
sought_after['count'].describe()
# Out:
# count     17.000000
# mean     462.764706
# std      224.245270
# min      213.000000
# 25%      271.000000
# 50%      437.000000
# 75%      568.000000
# max      913.000000
# Name: count, dtype: float64

# %%
plt.figure(figsize=(10,10))
ax = plt.subplot(111, polar=True)
plt.axis()

#set min and max value
lowerLimit = 0
max_v = sought_after['count'].max()

#set heights and width
heights =  sought_after['count']
width = 2*np.pi / len(sought_after.index)

#set index and angle
indexes = list(range(1, len(sought_after.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(x=angles, height=heights, width=width, bottom=lowerLimit,
              linewidth=1, edgecolor="white", color='blue')
labelPadding = 15

for bar, angle, height, label in zip(bars,angles, heights, sought_after['theme_name']):
    rotation = np.rad2deg(angle)
    alignment = ""
    #deal with alignment
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else:
        alignment = "left"
    ax.text(x=angle, y=lowerLimit + bar.get_height() + labelPadding,
            s=label, ha=alignment, va='center', rotation=rotation,
            rotation_mode="anchor")
    ax.set_thetagrids([], labels=[])
plt.show()
